# %% [markdown]
# <a href="https://colab.research.google.com/github/dansojo/Medical_CV/blob/main/MRI_Intensity_Adjustment_Normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **목표 : MRI 이미지를 0 ~ 1 범위로 정규화하여 데이터의 일관성 및 모델 학습에 적합한 형식으로 조정**

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io

# %%
# MRI 이미지 로드

image_path = '/content/drive/MyDrive/Medical_CV/MRI/MRI 이미지/MRI_T1C+.jpeg'
mri_image = io.imread(image_path, as_gray=True)

# %%
#  원본 이미지 데이터 확인
print(f"Original mri_image - Min Value: {mri_image.min()}, Max Value: {mri_image.max()}")
print(f"Original mri_image - Data Type: {mri_image.dtype}")
print(f"Original mri_image - Shape: {mri_image.shape}")
# Out:
# Original mri_image - Min Value: 9, Max Value: 255
# Original mri_image - Data Type: uint8
# Original mri_image - Shape: (630, 630)

# %%
# 2. 강도 정규화 (0-1 범위로 Min-Max Scaling)
# 이미지의 최소 및 최대 값 확인
min_val, max_val = np.min(mri_image), np.max(mri_image)
print(f"Original MRI Image - Min: {min_val}, Max: {max_val}")


# Min-Max Scaling을 통해 0-1 범위로 변환
normalized_image = (mri_image - min_val) / (max_val - min_val)
# 정규화 후 최소 및 최대 값 확인
print(f"Normalized MRI Image - Min: {normalized_image.min()}, Max: {normalized_image.max()}")
# Out:
# Original MRI Image - Min: 9, Max: 255
# Normalized MRI Image - Min: 0.0, Max: 1.0

# %% [markdown]
# **필터링 전후 시각화**

# %%
plt.figure(figsize=(14, 7))

# 원본 MRI 이미지
plt.subplot(1, 2, 1)
plt.imshow(mri_image, cmap='gray')
plt.title("Original MRI Image")
plt.axis('off')

# 정규화된 MRI 이미지
plt.subplot(1, 2, 2)
plt.imshow(normalized_image, cmap='gray')
plt.title("Normalized MRI Image (0-1)")
plt.axis('off')

plt.show()
